# %%
import vtk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scienceplots
from matplotlib.patches import FancyArrow
from matplotlib.patches import FancyArrowPatch
import findiff
import h5py as h5
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset
from IPython.display import display, Math, Latex
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import matplotlib.mlab as mplab
from scipy.signal import savgol_filter
from matplotlib.colors import Normalize
import matplotx
import seaborn as sns   
import matplotlib.colors
from matplotlib.colors import LogNorm
import cmasher as cmr
import seaborn as sns
import matplotlib.cm as cm
from matplotlib.ticker import ScalarFormatter
import glob
import os
import h5py

np.seterr(divide='ignore', invalid='ignore')
clrs = ['black','red','blue','green','magenta','yellow']

from collections import OrderedDict

linestyles = OrderedDict(
    [('solid',               (0, ())),
     ('loosely dotted',      (0, (1, 10))),
     ('dotted',              (0, (1, 5))),
     ('densely dotted',      (0, (1, 1))),

     ('loosely dashed',      (0, (5, 10))),
     ('dashed',              (0, (5, 5))),
     ('densely dashed',      (0, (5, 1))),

     ('loosely dashdotted',  (0, (3, 10, 1, 10))),
     ('dashdotted',          (0, (3, 5, 1, 5))),
     ('densely dashdotted',  (0, (3, 1, 1, 1))),

     ('loosely dashdotdotted', (0, (3, 10, 1, 10, 1, 10))),
     ('dashdotdotted',         (0, (3, 5, 1, 5, 1, 5))),
     ('densely dashdotdotted', (0, (3, 1, 1, 1, 1, 1)))])

lss = ['solid', 'dashed', 'dashdot', 'dotted', linestyles['densely dashdotdotted'], linestyles['densely dotted']]



cl0 = "#e41a1c"  # red
cl1 = "#377eb8"  # blue
cl2 = "#4daf4a"  # green
cl3 = "#984ea3"  # purple
cl4 = "#ff7f00"  # orange
cl5 = "#ffff33"  # yellow
cl6 = "#a65628"  # brown
cl7 = "#f781bf"  # pink
cl8 = "#999999"  # gray
cl9 = "#111111"  # near black

new_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
              '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
              '#bcbd22', '#17becf']

# %% [markdown]
# # $\textbf{1D\ linear\ convection:\ }$ $\frac{\partial u}{\partial t} + c \frac{\partial u}{\partial x} = 0$

# %%
# Space Grid
nx = 21
x_b = 0.0
x_e = 2.0
u_b = 1.0
u_e = 1.0
dx = (x_e - x_b)/(nx - 1)
x = np.linspace(x_b, x_e, nx)

# Time Grid
nt = 51
dt = 0.01
t_b = 0.0
t_e = nt * dt
t = np.linspace(t_b, t_e, nt)

# Equation Constants
c = 1.0

# %%
# Initial Solution
u = np.zeros(x.shape)
un = np.zeros(x.shape)

for i in np.arange(0, len(x)):

    if x[i] >= 0.5 and x[i] <= 1.0:
        u[i] = 2.0

    else:
        u[i] = 1.0

# %%
# Forward Difference in Time | Backward Difference in Space Scheme
for i in range(len(t)):

    # Dirichlet boundary conditions
    u[0] = u_b      # Left boundary
    u[-1] = u_e     # Right boundary

    un = u.copy()
    
    for j in range(1, len(x)-1):
        u[j] = un[j] - c * (dt / dx) * (un[j] - un[j-1])

print(u)
# Out:
# [1.         1.         1.         1.         1.         1.0046384
#  1.03092265 1.10393447 1.23643739 1.41310796 1.59763055 1.75017806
#  1.83616946 1.83177054 1.73569175 1.57601911 1.39853606 1.24395739
#  1.13255082 1.06420003 1.        ]
